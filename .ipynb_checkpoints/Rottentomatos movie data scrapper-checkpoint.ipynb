# %% [markdown]
# ## THE 84 BEST SUPERHERO MOVIES OF ALL TIME

# %%
#load packages
import requests
from bs4 import BeautifulSoup

# %%
# Define the URL of the site
base = 'https://editorial.rottentomatoes.com/guide/best-superhero-movies-of-all-time/'

# %%
# sending a request to the webpage
r = requests.get(base)
r.status_code
# Out:
# 200

# %%
html = r.content

# %%
soup = BeautifulSoup(html,'lxml')

# %%
with open('THE 84 BEST SUPERHERO_LXML_Parser.html', 'wb') as file:
    file.write(soup.prettify('utf-8'))

# %%
# Find all div tags on the webpage containing the information we want to scrape
divs = soup.find_all("div", {"class": "col-sm-18 col-full-xs countdown-item-content"})
divs
# Out:
# [<div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <h2><a href="//www.rottentomatoes.com/tv/the_haunting_of_hill_house">The Haunting of Hill House</a> <span class="subtle start-year">(2018)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">93%</span></h2>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#25</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> This modern reimagining of the Shirley Jackson novel follows siblings who, as children, grew up in what would go on...<a class="" data-pageheader="" href="//www.rottentomatoes.com/tv/the_haunting_of_hill_house" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/michiel-huisman">Michiel Huisman</a>, <a class="" href="//www.rottentomatoes.com/celebrity/carla_gugino">Carla Gugino</a>, <a class="" href="//www.rottentomatoes.com/celebrity/timothy_hutton">Timothy Hutton</a>, <a class="" href="//www.rottentomatoes.com/celebrity/elizabeth_reaser">Elizabeth Reaser</a></div>
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/mike_flanagan">Mike Flanagan</a>, <a class="" href="//www.rottentomatoes.com/celebrity/trevor_macy">Trevor Macy</a>, <a class="" href="//www.rottentomatoes.com/celebrity/meredith_averill">Meredith Averill</a>, <a class="" href="//www.rottentomatoes.com/celebrity/justin_falvey">Justin Falvey</a></div>
#  </div>
#  </div>
#  </div>,
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <h2><a href="//www.rottentomatoes.com/tv/the_great_british_bake_off">The Great British Bake Off</a> <span class="subtle start-year">(2010)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">90%</span></h2>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#24</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> Twelve amateur bakers compete against each other to win the title of Greatest British Baker. Each round sees an aspiring...<a class="" data-pageheader="" href="//www.rottentomatoes.com/tv/the_great_british_bake_off" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/paul_hollywood">Paul Hollywood</a>, <a class="" href="//www.rottentomatoes.com/celebrity/noel_fielding">Noel Fielding</a>, <a class="" href="//www.rottentomatoes.com/celebrity/prue_leith">Prue Leith</a>, <a class="" href="//www.rottentomatoes.com/celebrity/matt_lucas">Matt Lucas</a></div>
#  </div>
#  </div>
#  </div>,
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <h2><a href="//www.rottentomatoes.com/tv/westworld">Westworld</a> <span class="subtle start-year">(2016)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">80%</span></h2>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#23</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> Westworld isn't your typical amusement park. Intended for rich vacationers, the futuristic park -- which is looked after by robotic...<a class="" data-pageheader="" href="//www.rottentomatoes.com/tv/westworld" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/evan_rachel_wood">Evan Rachel Wood</a>, <a class="" href="//www.rottentomatoes.com/celebrity/thandiwe_newton">Thandie Newton</a>, <a class="" href="//www.rottentomatoes.com/celebrity/ed_harris">Ed Harris</a>, <a class="" href="//www.rottentomatoes.com/celebrity/jeffrey_wright">Jeffrey Wright</a></div>
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/jonathan_nolan">Jonathan Nolan</a>, <a class="" href="//www.rottentomatoes.com/celebrity/lisa_joy">Lisa Joy</a>, <a class="" href="//www.rottentomatoes.com/celebrity/jj_abrams">J.J. Abrams</a>, <a class="" href="//www.rottentomatoes.com/celebrity/athena_wickham">Athena Wickham</a></div>
#  </div>
#  </div>
#  </div>,
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <h2><a href="//www.rottentomatoes.com/tv/orange_is_the_new_black">Orange Is the New Black</a> <span class="subtle start-year">(2013)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">90%</span></h2>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#22</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> Piper Chapman is a public relations executive with a career and a fiance when her past suddenly catches up to...<a class="" data-pageheader="" href="//www.rottentomatoes.com/tv/orange_is_the_new_black" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/taylor_schilling">Taylor Schilling</a>, <a class="" href="//www.rottentomatoes.com/celebrity/natasha_lyonne">Natasha Lyonne</a>, <a class="" href="//www.rottentomatoes.com/celebrity/uzo_aduba">Uzo Aduba</a>, <a class="" href="//www.rottentomatoes.com/celebrity/danielle_brooks">Danielle Brooks</a></div>
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/andrew_mccarthy">Andrew McCarthy</a>, <a class="" href="//www.rottentomatoes.com/celebrity/phil_abraham">Phil Abraham</a>, <a class="" href="//www.rottentomatoes.com/celebrity/tara_herrmann">Tara Herrmann</a>, <a class="" href="//www.rottentomatoes.com/celebrity/jenji_kohan">Jenji Kohan</a></div>
#  </div>
#  </div>
#  </div>,
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <h2><a href="//www.rottentomatoes.com/tv/lucifer">Lucifer</a> <span class="subtle start-year">(2016)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">88%</span></h2>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#21</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> Based on characters created by Neil Gaiman, Sam Kieth and Mike Dringenberg, this series follows Lucifer, the original fallen angel,...<a class="" data-pageheader="" href="//www.rottentomatoes.com/tv/lucifer" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/tom_ellis">Tom Ellis</a>, <a class="" href="//www.rottentomatoes.com/celebrity/lauren_german">Lauren German</a>, <a class="" href="//www.rottentomatoes.com/celebrity/db_woodside">DB Woodside</a>, <a class="" href="//www.rottentomatoes.com/celebrity/kevin_alejandro">Kevin Alejandro</a></div>
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/nathan-hope">Nathan Hope</a></div>
#  </div>
#  </div>
#  </div>,
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <h2><a href="//www.rottentomatoes.com/tv/seinfeld">Seinfeld</a> <span class="subtle start-year">(1989)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">89%</span></h2>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#20</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> Four single friends -- comic Jerry Seinfeld, bungling George Costanza, frustrated working gal Elaine Benes and eccentric neighbor Cosmo Kramer...<a class="" data-pageheader="" href="//www.rottentomatoes.com/tv/seinfeld" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/jerry_seinfeld">Jerry Seinfeld</a>, <a class="" href="//www.rottentomatoes.com/celebrity/julia_louisdreyfus">Julia Louis-Dreyfus</a>, <a class="" href="//www.rottentomatoes.com/celebrity/jason_alexander">Jason Alexander</a>, <a class="" href="//www.rottentomatoes.com/celebrity/michael_richards">Michael Richards</a></div>
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/larry_david">Larry David</a>, <a class="" href="//www.rottentomatoes.com/celebrity/george_shapiro">George Shapiro</a>, <a class="" href="//www.rottentomatoes.com/celebrity/howard_west">Howard West</a></div>
#  </div>
#  </div>
#  </div>,
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <h2><a href="//www.rottentomatoes.com/tv/community">Community</a> <span class="subtle start-year">(2009)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">88%</span></h2>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#19</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> When fast-talking lawyer Jeff Winger (Joel McHale) finds his degree has been revoked, he is forced to go back to...<a class="" data-pageheader="" href="//www.rottentomatoes.com/tv/community" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/joel-mchale">Joel McHale</a>, <a class="" href="//www.rottentomatoes.com/celebrity/gillian-jacobs">Gillian Jacobs</a>, <a class="" href="//www.rottentomatoes.com/celebrity/danny_pudi">Danny Pudi</a>, <a class="" href="//www.rottentomatoes.com/celebrity/alison_brie">Alison Brie</a></div>
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/russ-krasnoff">Russ Krasnoff</a>, <a class="" href="//www.rottentomatoes.com/celebrity/dan_harmon_50">Dan Harmon</a>, <a class="" href="//www.rottentomatoes.com/celebrity/joseph_russo">Joe Russo</a>, <a class="" href="//www.rottentomatoes.com/celebrity/anthony_russo">Anthony Russo</a></div>
#  </div>
#  </div>
#  </div>,
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <h2><a href="//www.rottentomatoes.com/tv/buffy-the-vampire-slayer">Buffy the Vampire Slayer</a> <span class="subtle start-year">(1997)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">84%</span></h2>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#18</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> Sarah Michelle Gellar takes on the role of Buffy Summers in this TV version of "Buffy the Vampire Slayer," based...<a class="" data-pageheader="" href="//www.rottentomatoes.com/tv/buffy-the-vampire-slayer" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/sarah_michelle_gellar">Sarah Michelle Gellar</a>, <a class="" href="//www.rottentomatoes.com/celebrity/nicholas_brendon">Nicholas Brendon</a>, <a class="" href="//www.rottentomatoes.com/celebrity/alyson_hannigan">Alyson Hannigan</a>, <a class="" href="//www.rottentomatoes.com/celebrity/james_marsters">James Marsters</a></div>
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/1060778-joss_whedon">Joss Whedon</a>, <a class="" href="//www.rottentomatoes.com/celebrity/marti_noxon">Marti Noxon</a>, <a class="" href="//www.rottentomatoes.com/celebrity/david_fury">David Fury</a></div>
#  </div>
#  </div>
#  </div>,
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <h2><a href="//www.rottentomatoes.com/tv/sherlock">Sherlock</a> <span class="subtle start-year">(2010)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">78%</span></h2>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#17</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> In this contemporary version of Sir Arthur Conan Doyle's detective stories, Dr. John Watson is a war vet just home...<a class="" data-pageheader="" href="//www.rottentomatoes.com/tv/sherlock" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/benedict_cumberbatch">Benedict Cumberbatch</a>, <a class="" href="//www.rottentomatoes.com/celebrity/martin_freeman">Martin Freeman</a>, <a class="" href="//www.rottentomatoes.com/celebrity/andrew_scott_2">Andrew Scott</a>, <a class="" href="//www.rottentomatoes.com/celebrity/vinette_robinson">Vinette Robinson</a></div>
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/paul_mcguigan">Paul McGuigan</a></div>
#  </div>
#  </div>
#  </div>,
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <h2><a href="//www.rottentomatoes.com/tv/mindhunter">Mindhunter</a> <span class="subtle start-year">(2017)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">97%</span></h2>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#16</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> Catching a criminal often requires the authorities to get inside the villain's mind to figure out how he thinks. That's...<a class="" data-pageheader="" href="//www.rottentomatoes.com/tv/mindhunter" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/jonathan_groff">Jonathan Groff</a>, <a class="" href="//www.rottentomatoes.com/celebrity/holt_mccallany">Holt McCallany</a>, <a class="" href="//www.rottentomatoes.com/celebrity/anna_torv">Anna Torv</a>, <a class="" href="//www.rottentomatoes.com/celebrity/joe_tuttle">Joe Tuttle</a></div>
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/david_fincher">David Fincher</a>, <a class="" href="//www.rottentomatoes.com/celebrity/joshua_donen">Joshua Donen</a>, <a class="" href="//www.rottentomatoes.com/celebrity/charlize_theron">Charlize Theron</a>, <a class="" href="//www.rottentomatoes.com/celebrity/cean_chaffin">Ceán Chaffin</a></div>
#  </div>
#  </div>
#  </div>,
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <h2><a href="//www.rottentomatoes.com/tv/fleabag">Fleabag</a> <span class="subtle start-year">(2016)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">100%</span></h2>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#15</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> A dry-witted woman, known only as Fleabag, has no filter as she navigates life and love in London while trying...<a class="" data-pageheader="" href="//www.rottentomatoes.com/tv/fleabag" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/phoebe_waller_bridge">Phoebe Waller-Bridge</a>, <a class="" href="//www.rottentomatoes.com/celebrity/ben_aldridge">Ben Aldridge</a>, <a class="" href="//www.rottentomatoes.com/celebrity/sian_clifford">Sian Clifford</a>, <a class="" href="//www.rottentomatoes.com/celebrity/bill_paterson">Bill Paterson</a></div>
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/harry_bradbeer">Harry Bradbeer</a></div>
#  </div>
#  </div>
#  </div>,
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <h2><a href="//www.rottentomatoes.com/tv/daredevil">Marvel's Daredevil</a> <span class="subtle start-year">(2015)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">92%</span></h2>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#14</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> The first in a planned series of shows detailing the Marvel universe, "Daredevil" follows Matt Murdock, attorney by day and...<a class="" data-pageheader="" href="//www.rottentomatoes.com/tv/daredevil" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/1155812-charlie_cox">Charlie Cox</a>, <a class="" href="//www.rottentomatoes.com/celebrity/elodie_yung_2">Elodie Yung</a>, <a class="" href="//www.rottentomatoes.com/celebrity/deborah_ann_woll">Deborah Ann Woll</a>, <a class="" href="//www.rottentomatoes.com/celebrity/elden_ryan_ratliff">Elden Henson</a></div>
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/drew_goddard">Drew Goddard</a>, <a class="" href="//www.rottentomatoes.com/celebrity/jeph_loeb">Jeph Loeb</a>, <a class="" href="//www.rottentomatoes.com/celebrity/erik_oleson">Erik Oleson</a>, <a class="" href="//www.rottentomatoes.com/celebrity/jim_chory">Jim Chory</a></div>
#  </div>
#  </div>
#  </div>,
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <h2><a href="//www.rottentomatoes.com/tv/the_marvelous_mrs_maisel">The Marvelous Mrs. Maisel</a> <span class="subtle start-year">(2017)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">89%</span></h2>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#13</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> It's the late 1950s and Miriam "Midge" Maisel has everything she has ever wanted -- the perfect husband, two kids...<a class="" data-pageheader="" href="//www.rottentomatoes.com/tv/the_marvelous_mrs_maisel" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/rachel_brosnahan">Rachel Brosnahan</a>, <a class="" href="//www.rottentomatoes.com/celebrity/michael_zegen">Michael Zegen</a>, <a class="" href="//www.rottentomatoes.com/celebrity/alex_borstein">Alex Borstein</a>, <a class="" href="//www.rottentomatoes.com/celebrity/tony_shalhoub">Tony Shalhoub</a></div>
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/daniel_palladino">Daniel Palladino</a>, <a class="" href="//www.rottentomatoes.com/celebrity/amy_shermanpalladino">Amy Sherman-Palladino</a></div>
#  </div>
#  </div>
#  </div>,
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <h2><a href="//www.rottentomatoes.com/tv/black_mirror">Black Mirror</a> <span class="subtle start-year">(2011)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">84%</span></h2>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#12</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> Featuring stand-alone dramas -- sharp, suspenseful, satirical tales that explore techno-paranoia -- "Black Mirror" is a contemporary reworking of "The...<a class="" data-pageheader="" href="//www.rottentomatoes.com/tv/black_mirror" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> </div>
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/annabel_jones">Annabel Jones</a>, <a class="" href="//www.rottentomatoes.com/celebrity/charlie_brooker">Charlie Brooker</a></div>
#  </div>
#  </div>
#  </div>,
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <h2><a href="//www.rottentomatoes.com/tv/friends">Friends</a> <span class="subtle start-year">(1994)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">79%</span></h2>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#11</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> Three young men and three young women -- of the BFF kind -- live in the same apartment complex and...<a class="" data-pageheader="" href="//www.rottentomatoes.com/tv/friends" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/jennifer_aniston">Jennifer Aniston</a>, <a class="" href="//www.rottentomatoes.com/celebrity/courteney_cox">Courteney Cox Arquette</a>, <a class="" href="//www.rottentomatoes.com/celebrity/lisa_kudrow">Lisa Kudrow</a>, <a class="" href="//www.rottentomatoes.com/celebrity/matt_leblanc">Matt LeBlanc</a></div>
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/kevin_s_bright_2">Kevin S. Bright</a>, <a class="" href="//www.rottentomatoes.com/celebrity/david_crane_6">David Crane</a>, <a class="" href="//www.rottentomatoes.com/celebrity/greg_malins">Greg Malins</a>, <a class="" href="//www.rottentomatoes.com/celebrity/wil_calhoun">Wil Calhoun</a></div>
#  </div>
#  </div>
#  </div>,
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <h2><a href="//www.rottentomatoes.com/tv/the_boys_2019">The Boys</a> <span class="subtle start-year">(2019)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">93%</span></h2>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#10</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> Superheroes are often as popular as celebrities, as influential as politicians, and sometimes even as revered as gods. But that's...<a class="" data-pageheader="" href="//www.rottentomatoes.com/tv/the_boys_2019" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/karl_urban">Karl Urban</a>, <a class="" href="//www.rottentomatoes.com/celebrity/jack_quaid">Jack Quaid</a>, <a class="" href="//www.rottentomatoes.com/celebrity/antony_starr">Antony Starr</a>, <a class="" href="//www.rottentomatoes.com/celebrity/erin_moriarty_3">Erin Moriarty</a></div>
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/eric_kripke">Eric Kripke</a>, <a class="" href="//www.rottentomatoes.com/celebrity/sethrogen">Seth Rogen</a>, <a class="" href="//www.rottentomatoes.com/celebrity/evan_goldberg">Evan Goldberg</a>, <a class="" href="//www.rottentomatoes.com/celebrity/james_weaver_2">James Weaver</a></div>
#  </div>
#  </div>
#  </div>,
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <h2><a href="//www.rottentomatoes.com/tv/downton_abbey">Downton Abbey</a> <span class="subtle start-year">(2010)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">91%</span></h2>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#9</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> This British drama series follows the lives of the Crawley family and its servants in the family's classic Georgian country...<a class="" data-pageheader="" href="//www.rottentomatoes.com/tv/downton_abbey" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/maggie_smith">Maggie Smith</a>, <a class="" href="//www.rottentomatoes.com/celebrity/hugh_bonneville">Hugh Bonneville</a>, <a class="" href="//www.rottentomatoes.com/celebrity/elizabeth_mcgovern">Elizabeth McGovern</a>, <a class="" href="//www.rottentomatoes.com/celebrity/brendan_coyle">Brendan Coyle</a></div>
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/julian_fellowes">Julian Fellowes</a></div>
#  </div>
#  </div>
#  </div>,
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <h2><a href="//www.rottentomatoes.com/tv/schitts_creek">Schitt's Creek</a> <span class="subtle start-year">(2015)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">93%</span></h2>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#8</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> In the sitcom "Schitt's Creek," a wealthy couple -- video store magnate Johnny and his soap opera star wife Moira...<a class="" data-pageheader="" href="//www.rottentomatoes.com/tv/schitts_creek" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/eugene_levy">Eugene Levy</a>, <a class="" href="//www.rottentomatoes.com/celebrity/catherine_ohara">Catherine O'Hara</a>, <a class="" href="//www.rottentomatoes.com/celebrity/dan_levy_2">Daniel Levy</a>, <a class="" href="//www.rottentomatoes.com/celebrity/annie_murphy">Annie Murphy</a></div>
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/andrew_barnsley">Andrew Barnsley</a>, <a class="" href="//www.rottentomatoes.com/celebrity/dan_levy_2">Daniel Levy</a>, <a class="" href="//www.rottentomatoes.com/celebrity/eugene_levy">Eugene Levy</a>, <a class="" href="//www.rottentomatoes.com/celebrity/fred_levy">Fred Levy</a></div>
#  </div>
#  </div>
#  </div>,
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <h2><a href="//www.rottentomatoes.com/tv/ozark">Ozark</a> <span class="subtle start-year">(2017)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">83%</span></h2>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#7</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> Created by Bill Dubuque ("The Accountant," "The Judge"), this drama series stars Jason Bateman as Marty Byrde, a financial planner...<a class="" data-pageheader="" href="//www.rottentomatoes.com/tv/ozark" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/jason_bateman">Jason Bateman</a>, <a class="" href="//www.rottentomatoes.com/celebrity/laura_linney">Laura Linney</a>, <a class="" href="//www.rottentomatoes.com/celebrity/sofia_hublitz">Sofia Hublitz</a>, <a class="" href="//www.rottentomatoes.com/celebrity/skylar_gaertner">Skylar Gaertner</a></div>
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/jason_bateman">Jason Bateman</a>, <a class="" href="//www.rottentomatoes.com/celebrity/chris_mundy">Chris Mundy</a>, <a class="" href="//www.rottentomatoes.com/celebrity/bill_dubuque">Bill Dubuque</a>, <a class="" href="//www.rottentomatoes.com/celebrity/mark_williams_2">Mark Williams</a></div>
#  </div>
#  </div>
#  </div>,
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <h2><a href="//www.rottentomatoes.com/tv/parks_and_recreation">Parks and Recreation</a> <span class="subtle start-year">(2009)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">93%</span></h2>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#6</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> Leslie Knope, a midlevel bureaucrat in an Indiana Parks and Recreation Department, hopes to beautify her town (and boost her...<a class="" data-pageheader="" href="//www.rottentomatoes.com/tv/parks_and_recreation" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/amy_poehler">Amy Poehler</a>, <a class="" href="//www.rottentomatoes.com/celebrity/aziz_ansari">Aziz Ansari</a>, <a class="" href="//www.rottentomatoes.com/celebrity/nick-offerman">Nick Offerman</a>, <a class="" href="//www.rottentomatoes.com/celebrity/aubrey_plaza">Aubrey Plaza</a></div>
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/greg_daniels">Greg Daniels</a>, <a class="" href="//www.rottentomatoes.com/celebrity/mike_schur">Michael Schur</a>, <a class="" href="//www.rottentomatoes.com/celebrity/howard_klein">Howard Klein</a>, <a class="" href="//www.rottentomatoes.com/celebrity/david_miner">David Miner</a></div>
#  </div>
#  </div>
#  </div>,
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <h2><a href="//www.rottentomatoes.com/tv/the_office">The Office</a> <span class="subtle start-year">(2005)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">81%</span></h2>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#5</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> This U.S. adaptation -- set at a paper company based in Scranton, Pa. -- has a similar documentary style to...<a class="" data-pageheader="" href="//www.rottentomatoes.com/tv/the_office" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/steve_carell">Steve Carell</a>, <a class="" href="//www.rottentomatoes.com/celebrity/rainn_wilson">Rainn Wilson</a>, <a class="" href="//www.rottentomatoes.com/celebrity/john_krasinksi">John Krasinski</a>, <a class="" href="//www.rottentomatoes.com/celebrity/jenna_fischer">Jenna Fischer</a></div>
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/ben_silverman">Ben Silverman</a>, <a class="" href="//www.rottentomatoes.com/celebrity/greg_daniels">Greg Daniels</a>, <a class="" href="//www.rottentomatoes.com/celebrity/ricky_gervais">Ricky Gervais</a>, <a class="" href="//www.rottentomatoes.com/celebrity/stephen_merchant">Stephen Merchant</a></div>
#  </div>
#  </div>
#  </div>,
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <h2><a href="//www.rottentomatoes.com/tv/game_of_thrones">Game of Thrones</a> <span class="subtle start-year">(2011)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">89%</span></h2>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#4</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> George R.R. Martin's best-selling book series "A Song of Ice and Fire" is brought to the screen as HBO sinks...<a class="" data-pageheader="" href="//www.rottentomatoes.com/tv/game_of_thrones" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/peter_dinklage">Peter Dinklage</a>, <a class="" href="//www.rottentomatoes.com/celebrity/nikolaj_waldau">Nikolaj Coster-Waldau</a>, <a class="" href="//www.rottentomatoes.com/celebrity/lena_headey">Lena Headey</a>, <a class="" href="//www.rottentomatoes.com/celebrity/emilia_clarke">Emilia Clarke</a></div>
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/david_benioff">David Benioff</a>, <a class="" href="//www.rottentomatoes.com/celebrity/db_weiss">D.B. Weiss</a></div>
#  </div>
#  </div>
#  </div>,
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <h2><a href="//www.rottentomatoes.com/tv/breaking_bad">Breaking Bad</a> <span class="subtle start-year">(2008)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">96%</span></h2>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#3</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> Mild-mannered high school chemistry teacher Walter White thinks his life can't get much worse. His salary barely makes ends meet,...<a class="" data-pageheader="" href="//www.rottentomatoes.com/tv/breaking_bad" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/bryan_cranston">Bryan Cranston</a>, <a class="" href="//www.rottentomatoes.com/celebrity/aaron_paul">Aaron Paul</a>, <a class="" href="//www.rottentomatoes.com/celebrity/anna_gunn">Anna Gunn</a>, <a class="" href="//www.rottentomatoes.com/celebrity/rj_mitte">RJ Mitte</a></div>
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/vince_gilligan">Vince Gilligan</a>, <a class="" href="//www.rottentomatoes.com/celebrity/mark_johnson_7">Mark Johnson</a>, <a class="" href="//www.rottentomatoes.com/celebrity/michelle_maxwell_maclaren">Michelle MacLaren</a>, <a class="" href="//www.rottentomatoes.com/celebrity/adam_bernstein">Adam Bernstein</a></div>
#  </div>
#  </div>
#  </div>,
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <h2><a href="//www.rottentomatoes.com/tv/the_mandalorian">The Mandalorian</a> <span class="subtle start-year">(2019)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">93%</span></h2>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#2</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> After the fall of the Galactic Empire, a lone gunfighter makes his way through the outer reaches of the lawless...<a class="" data-pageheader="" href="//www.rottentomatoes.com/tv/the_mandalorian" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/pedro_pascal">Pedro Pascal</a>, <a class="" href="//www.rottentomatoes.com/celebrity/gina_carano">Gina Carano</a>, <a class="" href="//www.rottentomatoes.com/celebrity/carl_weathers">Carl Weathers</a>, <a class="" href="//www.rottentomatoes.com/celebrity/giancarlo_esposito">Giancarlo Esposito</a></div>
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/dave-filoni">Dave Filoni</a>, <a class="" href="//www.rottentomatoes.com/celebrity/kathleen_kennedy">Kathleen Kennedy</a>, <a class="" href="//www.rottentomatoes.com/celebrity/1053102-colin_wilson">Colin Wilson</a></div>
#  </div>
#  </div>
#  </div>,
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <h2><a href="//www.rottentomatoes.com/tv/stranger_things">Stranger Things</a> <span class="subtle start-year">(2016)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">91%</span></h2>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#1</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> Mysteries unravel in a small Midwestern town in the 1980s, involving supernatural forces, secret experiments and one strange girl....<a class="" data-pageheader="" href="//www.rottentomatoes.com/tv/stranger_things" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/winona_ryder">Winona Ryder</a>, <a class="" href="//www.rottentomatoes.com/celebrity/david_harbour">David Harbour</a>, <a class="" href="//www.rottentomatoes.com/celebrity/millie_brown">Millie Bobby Brown</a>, <a class="" href="//www.rottentomatoes.com/celebrity/finn_wolfhard">Finn Wolfhard</a></div>
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/matt_duffer">Matt Duffer</a>, <a class="" href="//www.rottentomatoes.com/celebrity/ross_duffer">Ross Duffer</a>, <a class="" href="//www.rottentomatoes.com/celebrity/1048166-shawn_levy">Shawn Levy</a>, <a class="" href="//www.rottentomatoes.com/celebrity/dan_cohen_3">Dan Cohen</a></div>
#  </div>
#  </div>
#  </div>]

# %%
divs[0].find("h2")
# Out:
# <h2><a href="//www.rottentomatoes.com/tv/the_haunting_of_hill_house">The Haunting of Hill House</a> <span class="subtle start-year">(2018)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">93%</span></h2>

# %%
headings = [div.find("h2") for div in divs]

# %%
movie_names = [heading.find('a').string for heading in headings]
movie_names
# Out:
# ['The Haunting of Hill House',
#  'The Great British Bake Off',
#  'Westworld',
#  'Orange Is the New Black',
#  'Lucifer',
#  'Seinfeld',
#  'Community',
#  'Buffy the Vampire Slayer',
#  'Sherlock',
#  'Mindhunter',
#  'Fleabag',
#  "Marvel's Daredevil",
#  'The Marvelous Mrs. Maisel',
#  'Black Mirror',
#  'Friends',
#  'The Boys',
#  'Downton Abbey',
#  "Schitt's Creek",
#  'Ozark',
#  'Parks and Recreation',
#  'The Office',
#  'Game of Thrones',
#  'Breaking Bad',
#  'The Mandalorian',
#  'Stranger Things']

# %%
years = [heading.find("span", class_ = 'start-year').string for heading in headings]
years = ["2000" if x == '()' else x for x in years]
years
# Out:
# ['(2018)',
#  '(2010)',
#  '(2016)',
#  '(2013)',
#  '(2016)',
#  '(1989)',
#  '(2009)',
#  '(1997)',
#  '(2010)',
#  '(2017)',
#  '(2016)',
#  '(2015)',
#  '(2017)',
#  '(2011)',
#  '(1994)',
#  '(2019)',
#  '(2010)',
#  '(2015)',
#  '(2017)',
#  '(2009)',
#  '(2005)',
#  '(2011)',
#  '(2008)',
#  '(2019)',
#  '(2016)']

# %%
years = [year.strip('()') for year in years]
#years = [int(year) for year in years]
years
# Out:
# ['2018',
#  '2010',
#  '2016',
#  '2013',
#  '2016',
#  '1989',
#  '2009',
#  '1997',
#  '2010',
#  '2017',
#  '2016',
#  '2015',
#  '2017',
#  '2011',
#  '1994',
#  '2019',
#  '2010',
#  '2015',
#  '2017',
#  '2009',
#  '2005',
#  '2011',
#  '2008',
#  '2019',
#  '2016']

# %%
scores = [heading.find("span", class_ = 'tMeterScore').string for heading in headings]

scores = ["69" if x is None else x for x in scores]
scores = [s.strip('%') for s in scores]


#scores = [int(s) for s in scores]
scores
# Out:
# ['93',
#  '90',
#  '80',
#  '90',
#  '88',
#  '89',
#  '88',
#  '84',
#  '78',
#  '97',
#  '100',
#  '92',
#  '89',
#  '84',
#  '79',
#  '93',
#  '91',
#  '93',
#  '83',
#  '93',
#  '81',
#  '89',
#  '96',
#  '93',
#  '91']

# %%
consensus = [soup.new_string("") if div.find("div", {"class": "info critics-consensus"}) is None else div.find("div", {"class": "info critics-consensus"}) for div in divs]
consensus
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
[con.text for con in consensus]
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
common_phrase = 'Critics Consensus: '
len(common_phrase)
# Out:
# 19

# %%
consensus[0].text
# Out:
# ''

# %%
consensus[0].text[19:]
# Out:
# ''

# %%
common_len = len(common_phrase)
consensus_text = [con.text[common_len:] for con in consensus]
consensus_text
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
# We can add if-else logic to only truncate the string in case it starts with the common phrase
consensus_text = [con.text[common_len:] if con.text.startswith(common_phrase) else con.text for con in consensus ]
consensus_text
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
divs[0]
# Out:
# <div class="col-sm-18 col-full-xs countdown-item-content">
# <div class="row countdown-item-title-bar">
# <div class="col-sm-20 col-full-xs" style="height: 100%;">
# <div class="article_movie_title" style="float: left;">
# <h2><a href="//www.rottentomatoes.com/tv/the_haunting_of_hill_house">The Haunting of Hill House</a> <span class="subtle start-year">(2018)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">93%</span></h2>
# </div>
# </div>
# <div class="col-sm-4 col-full-xs" style="height: 100%;">
# <div class="countdown-index">#25</div>
# </div>
# </div>
# <div class="row countdown-item-details">
# <div class="col-sm-24">
# <div class="info synopsis"><span class="descriptor">Synopsis:</span> This modern reimagining of the Shirley Jackson novel follows siblings who, as children, grew up in what would go on...<a class="" data-pageheader="" href="//www.rottentomatoes.com/tv/the_haunting_of_hill_house" target="_top"> [More]</a></div>
# <div class="info cast">
# <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/michiel-huisman">Michiel Huisman</a>, <a class="" href="//www.rottentomatoes.com/celebrity/carla_gugino">Carla Gugino</a>, <a class="" href="//www.rottentomatoes.com/celebrity/timothy_hutton">Timothy Hutton</a>, <a class="" href="//www.rottentomatoes.com/celebrity/elizabeth_reaser">Elizabeth Reaser</a></div>
# <div class="info director">
# <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/mike_flanagan">Mike Flanagan</a>, <a class="" href="//www.rottentomatoes.com/celebrity/trevor_macy">Trevor Macy</a>, <a class="" href="//www.rottentomatoes.com/celebrity/meredith_averill">Meredith Averill</a>, <a class="" href="//www.rottentomatoes.com/celebrity/justin_falvey">Justin Falvey</a></div>
# </div>
# </div>
# </div>

# %%
div_casts= [div.find("div",{"class": "info cast"}) for div in  divs]
casts_link = div_casts[0].find_all("a")
cast_names = [link.string for link in casts_link]

# %%
# cast = []
# for c in div_casts:
#     casts_link = c.find_all("a")
#     cast_names = [link.string for link in casts_link]
#     cast.append(", ".join(cast_names)) # Joining is optional
    
# cast
#cast_info = [div.find("div", class_ = 'cast') for div in divs]

# %%
cast =  [soup.new_string("") if c is None else  ", ".join([link.string for link in c.find_all("a")]) for c in div_casts]
cast
# Out:
# ['Michiel Huisman, Carla Gugino, Timothy Hutton, Elizabeth Reaser',
#  'Paul Hollywood, Noel Fielding, Prue Leith, Matt Lucas',
#  'Evan Rachel Wood, Thandie Newton, Ed Harris, Jeffrey Wright',
#  'Taylor Schilling, Natasha Lyonne, Uzo Aduba, Danielle Brooks',
#  'Tom Ellis, Lauren German, DB Woodside, Kevin Alejandro',
#  'Jerry Seinfeld, Julia Louis-Dreyfus, Jason Alexander, Michael Richards',
#  'Joel McHale, Gillian Jacobs, Danny Pudi, Alison Brie',
#  'Sarah Michelle Gellar, Nicholas Brendon, Alyson Hannigan, James Marsters',
#  'Benedict Cumberbatch, Martin Freeman, Andrew Scott, Vinette Robinson',
#  'Jonathan Groff, Holt McCallany, Anna Torv, Joe Tuttle',
#  'Phoebe Waller-Bridge, Ben Aldridge, Sian Clifford, Bill Paterson',
#  'Charlie Cox, Elodie Yung, Deborah Ann Woll, Elden Henson',
#  'Rachel Brosnahan, Michael Zegen, Alex Borstein, Tony Shalhoub',
#  '',
#  'Jennifer Aniston, Courteney Cox Arquette, Lisa Kudrow, Matt LeBlanc',
#  'Karl Urban, Jack Quaid, Antony Starr, Erin Moriarty',
#  'Maggie Smith, Hugh Bonneville, Elizabeth McGovern, Brendan Coyle',
#  "Eugene Levy, Catherine O'Hara, Daniel Levy, Annie Murphy",
#  'Jason Bateman, Laura Linney, Sofia Hublitz, Skylar Gaertner',
#  'Amy Poehler, Aziz Ansari, Nick Offerman, Aubrey Plaza',
#  'Steve Carell, Rainn Wilson, John Krasinski, Jenna Fischer',
#  'Peter Dinklage, Nikolaj Coster-Waldau, Lena Headey, Emilia Clarke',
#  'Bryan Cranston, Aaron Paul, Anna Gunn, RJ Mitte',
#  'Pedro Pascal, Gina Carano, Carl Weathers, Giancarlo Esposito',
#  'Winona Ryder, David Harbour, Millie Bobby Brown, Finn Wolfhard']

# %%
# Extracting all director divs
directors= [soup.new_tag("div") if div.find("div",class_= "info director") is None else div.find("div",class_= "info director") for div in divs]
directors
# Out:
# [<div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/mike_flanagan">Mike Flanagan</a>, <a class="" href="//www.rottentomatoes.com/celebrity/trevor_macy">Trevor Macy</a>, <a class="" href="//www.rottentomatoes.com/celebrity/meredith_averill">Meredith Averill</a>, <a class="" href="//www.rottentomatoes.com/celebrity/justin_falvey">Justin Falvey</a></div>,
#  <div></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/jonathan_nolan">Jonathan Nolan</a>, <a class="" href="//www.rottentomatoes.com/celebrity/lisa_joy">Lisa Joy</a>, <a class="" href="//www.rottentomatoes.com/celebrity/jj_abrams">J.J. Abrams</a>, <a class="" href="//www.rottentomatoes.com/celebrity/athena_wickham">Athena Wickham</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/andrew_mccarthy">Andrew McCarthy</a>, <a class="" href="//www.rottentomatoes.com/celebrity/phil_abraham">Phil Abraham</a>, <a class="" href="//www.rottentomatoes.com/celebrity/tara_herrmann">Tara Herrmann</a>, <a class="" href="//www.rottentomatoes.com/celebrity/jenji_kohan">Jenji Kohan</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/nathan-hope">Nathan Hope</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/larry_david">Larry David</a>, <a class="" href="//www.rottentomatoes.com/celebrity/george_shapiro">George Shapiro</a>, <a class="" href="//www.rottentomatoes.com/celebrity/howard_west">Howard West</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/russ-krasnoff">Russ Krasnoff</a>, <a class="" href="//www.rottentomatoes.com/celebrity/dan_harmon_50">Dan Harmon</a>, <a class="" href="//www.rottentomatoes.com/celebrity/joseph_russo">Joe Russo</a>, <a class="" href="//www.rottentomatoes.com/celebrity/anthony_russo">Anthony Russo</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/1060778-joss_whedon">Joss Whedon</a>, <a class="" href="//www.rottentomatoes.com/celebrity/marti_noxon">Marti Noxon</a>, <a class="" href="//www.rottentomatoes.com/celebrity/david_fury">David Fury</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/paul_mcguigan">Paul McGuigan</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/david_fincher">David Fincher</a>, <a class="" href="//www.rottentomatoes.com/celebrity/joshua_donen">Joshua Donen</a>, <a class="" href="//www.rottentomatoes.com/celebrity/charlize_theron">Charlize Theron</a>, <a class="" href="//www.rottentomatoes.com/celebrity/cean_chaffin">Ceán Chaffin</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/harry_bradbeer">Harry Bradbeer</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/drew_goddard">Drew Goddard</a>, <a class="" href="//www.rottentomatoes.com/celebrity/jeph_loeb">Jeph Loeb</a>, <a class="" href="//www.rottentomatoes.com/celebrity/erik_oleson">Erik Oleson</a>, <a class="" href="//www.rottentomatoes.com/celebrity/jim_chory">Jim Chory</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/daniel_palladino">Daniel Palladino</a>, <a class="" href="//www.rottentomatoes.com/celebrity/amy_shermanpalladino">Amy Sherman-Palladino</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/annabel_jones">Annabel Jones</a>, <a class="" href="//www.rottentomatoes.com/celebrity/charlie_brooker">Charlie Brooker</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/kevin_s_bright_2">Kevin S. Bright</a>, <a class="" href="//www.rottentomatoes.com/celebrity/david_crane_6">David Crane</a>, <a class="" href="//www.rottentomatoes.com/celebrity/greg_malins">Greg Malins</a>, <a class="" href="//www.rottentomatoes.com/celebrity/wil_calhoun">Wil Calhoun</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/eric_kripke">Eric Kripke</a>, <a class="" href="//www.rottentomatoes.com/celebrity/sethrogen">Seth Rogen</a>, <a class="" href="//www.rottentomatoes.com/celebrity/evan_goldberg">Evan Goldberg</a>, <a class="" href="//www.rottentomatoes.com/celebrity/james_weaver_2">James Weaver</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/julian_fellowes">Julian Fellowes</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/andrew_barnsley">Andrew Barnsley</a>, <a class="" href="//www.rottentomatoes.com/celebrity/dan_levy_2">Daniel Levy</a>, <a class="" href="//www.rottentomatoes.com/celebrity/eugene_levy">Eugene Levy</a>, <a class="" href="//www.rottentomatoes.com/celebrity/fred_levy">Fred Levy</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/jason_bateman">Jason Bateman</a>, <a class="" href="//www.rottentomatoes.com/celebrity/chris_mundy">Chris Mundy</a>, <a class="" href="//www.rottentomatoes.com/celebrity/bill_dubuque">Bill Dubuque</a>, <a class="" href="//www.rottentomatoes.com/celebrity/mark_williams_2">Mark Williams</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/greg_daniels">Greg Daniels</a>, <a class="" href="//www.rottentomatoes.com/celebrity/mike_schur">Michael Schur</a>, <a class="" href="//www.rottentomatoes.com/celebrity/howard_klein">Howard Klein</a>, <a class="" href="//www.rottentomatoes.com/celebrity/david_miner">David Miner</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/ben_silverman">Ben Silverman</a>, <a class="" href="//www.rottentomatoes.com/celebrity/greg_daniels">Greg Daniels</a>, <a class="" href="//www.rottentomatoes.com/celebrity/ricky_gervais">Ricky Gervais</a>, <a class="" href="//www.rottentomatoes.com/celebrity/stephen_merchant">Stephen Merchant</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/david_benioff">David Benioff</a>, <a class="" href="//www.rottentomatoes.com/celebrity/db_weiss">D.B. Weiss</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/vince_gilligan">Vince Gilligan</a>, <a class="" href="//www.rottentomatoes.com/celebrity/mark_johnson_7">Mark Johnson</a>, <a class="" href="//www.rottentomatoes.com/celebrity/michelle_maxwell_maclaren">Michelle MacLaren</a>, <a class="" href="//www.rottentomatoes.com/celebrity/adam_bernstein">Adam Bernstein</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/dave-filoni">Dave Filoni</a>, <a class="" href="//www.rottentomatoes.com/celebrity/kathleen_kennedy">Kathleen Kennedy</a>, <a class="" href="//www.rottentomatoes.com/celebrity/1053102-colin_wilson">Colin Wilson</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/matt_duffer">Matt Duffer</a>, <a class="" href="//www.rottentomatoes.com/celebrity/ross_duffer">Ross Duffer</a>, <a class="" href="//www.rottentomatoes.com/celebrity/1048166-shawn_levy">Shawn Levy</a>, <a class="" href="//www.rottentomatoes.com/celebrity/dan_cohen_3">Dan Cohen</a></div>]

# %%
director= []

for d in directors:
    if d!=None:
        director_link = d.find_all("a")
        director_name = [link.string for link in director_link]
        director.append(", ".join(director_name)) # Joining is optional
    
    
    
director
# Out:
# ['Mike Flanagan, Trevor Macy, Meredith Averill, Justin Falvey',
#  '',
#  'Jonathan Nolan, Lisa Joy, J.J. Abrams, Athena Wickham',
#  'Andrew McCarthy, Phil Abraham, Tara Herrmann, Jenji Kohan',
#  'Nathan Hope',
#  'Larry David, George Shapiro, Howard West',
#  'Russ Krasnoff, Dan Harmon, Joe Russo, Anthony Russo',
#  'Joss Whedon, Marti Noxon, David Fury',
#  'Paul McGuigan',
#  'David Fincher, Joshua Donen, Charlize Theron, Ceán Chaffin',
#  'Harry Bradbeer',
#  'Drew Goddard, Jeph Loeb, Erik Oleson, Jim Chory',
#  'Daniel Palladino, Amy Sherman-Palladino',
#  'Annabel Jones, Charlie Brooker',
#  'Kevin S. Bright, David Crane, Greg Malins, Wil Calhoun',
#  'Eric Kripke, Seth Rogen, Evan Goldberg, James Weaver',
#  'Julian Fellowes',
#  'Andrew Barnsley, Daniel Levy, Eugene Levy, Fred Levy',
#  'Jason Bateman, Chris Mundy, Bill Dubuque, Mark Williams',
#  'Greg Daniels, Michael Schur, Howard Klein, David Miner',
#  'Ben Silverman, Greg Daniels, Ricky Gervais, Stephen Merchant',
#  'David Benioff, D.B. Weiss',
#  'Vince Gilligan, Mark Johnson, Michelle MacLaren, Adam Bernstein',
#  'Dave Filoni, Kathleen Kennedy, Colin Wilson',
#  'Matt Duffer, Ross Duffer, Shawn Levy, Dan Cohen']

# %%
tag_div = soup.find("div")
count_children = len(tag_div.find_all())
print(count_children)
# Out:
# 38

# %%
synopsis = [soup.new_string("") if div.find("div",class_="info synopsis") is None else  div.find("div",class_="info synopsis") for div in divs]
synopsis[0]
# Out:
# <div class="info synopsis"><span class="descriptor">Synopsis:</span> This modern reimagining of the Shirley Jackson novel follows siblings who, as children, grew up in what would go on...<a class="" data-pageheader="" href="//www.rottentomatoes.com/tv/the_haunting_of_hill_house" target="_top"> [More]</a></div>

# %%
cm_phrase = "Synopsis:"
cm_len=len(cm_phrase)

# %%
synopsis_texts = [ syn.text[cm_len:] for syn in synopsis]
synopsis_texts
# Out:
# [' This modern reimagining of the Shirley Jackson novel follows siblings who, as children, grew up in what would go on... [More]',
#  ' Twelve amateur bakers compete against each other to win the title of Greatest British Baker. Each round sees an aspiring... [More]',
#  " Westworld isn't your typical amusement park. Intended for rich vacationers, the futuristic park -- which is looked after by robotic... [More]",
#  ' Piper Chapman is a public relations executive with a career and a fiance when her past suddenly catches up to... [More]',
#  ' Based on characters created by Neil Gaiman, Sam Kieth and Mike Dringenberg, this series follows Lucifer, the original fallen angel,... [More]',
#  ' Four single friends -- comic Jerry Seinfeld, bungling George Costanza, frustrated working gal Elaine Benes and eccentric neighbor Cosmo Kramer... [More]',
#  ' When fast-talking lawyer Jeff Winger (Joel McHale) finds his degree has been revoked, he is forced to go back to... [More]',
#  ' Sarah Michelle Gellar takes on the role of Buffy Summers in this TV version of "Buffy the Vampire Slayer," based... [More]',
#  " In this contemporary version of Sir Arthur Conan Doyle's detective stories, Dr. John Watson is a war vet just home... [More]",
#  " Catching a criminal often requires the authorities to get inside the villain's mind to figure out how he thinks. That's... [More]",
#  ' A dry-witted woman, known only as Fleabag, has no filter as she navigates life and love in London while trying... [More]',
#  ' The first in a planned series of shows detailing the Marvel universe, "Daredevil" follows Matt Murdock, attorney by day and... [More]',
#  ' It\'s the late 1950s and Miriam "Midge" Maisel has everything she has ever wanted -- the perfect husband, two kids... [More]',
#  ' Featuring stand-alone dramas -- sharp, suspenseful, satirical tales that explore techno-paranoia -- "Black Mirror" is a contemporary reworking of "The... [More]',
#  ' Three young men and three young women -- of the BFF kind -- live in the same apartment complex and... [More]',
#  " Superheroes are often as popular as celebrities, as influential as politicians, and sometimes even as revered as gods. But that's... [More]",
#  " This British drama series follows the lives of the Crawley family and its servants in the family's classic Georgian country... [More]",
#  ' In the sitcom "Schitt\'s Creek," a wealthy couple -- video store magnate Johnny and his soap opera star wife Moira... [More]',
#  ' Created by Bill Dubuque ("The Accountant," "The Judge"), this drama series stars Jason Bateman as Marty Byrde, a financial planner... [More]',
#  ' Leslie Knope, a midlevel bureaucrat in an Indiana Parks and Recreation Department, hopes to beautify her town (and boost her... [More]',
#  ' This U.S. adaptation -- set at a paper company based in Scranton, Pa. -- has a similar documentary style to... [More]',
#  ' George R.R. Martin\'s best-selling book series "A Song of Ice and Fire" is brought to the screen as HBO sinks... [More]',
#  " Mild-mannered high school chemistry teacher Walter White thinks his life can't get much worse. His salary barely makes ends meet,... [More]",
#  ' After the fall of the Galactic Empire, a lone gunfighter makes his way through the outer reaches of the lawless... [More]',
#  ' Mysteries unravel in a small Midwestern town in the 1980s, involving supernatural forces, secret experiments and one strange girl.... [More]']

# %%
genre=[]
for i in range(84):
    genre.append("Super-hero")

# %%
Platform=[]
for i in range(84):
    
        Platform.append("public")

# %%
# load the pandas package
import pandas as pd

# %%
# A dataframe is a tabular data type, frequently used in data science

movies_info = pd.DataFrame()
movies_info  # The dataframe is still empty, we need to fill it with the info we gathered
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
movies_info["Movie Title"] = movie_names
movies_info["Year"] = years
movies_info["Score"] = scores
movies_info["Director"] = director
movies_info["Synopsis"] = synopsis_texts    # Homework
movies_info["Cast"] = cast
movies_info["Genre"] = genre
movies_info["Critic_Consensus"] = consensus_text
movies_info['Platform']=Platform
# Let's see how it looks
movies_info
# Out:
#                    Movie Title  Year Score  \
# 0   The Haunting of Hill House  2018    93
# 1   The Great British Bake Off  2010    90
# 2                    Westworld  2016    80
# 3      Orange Is the New Black  2013    90
# 4                      Lucifer  2016    88
# 5                     Seinfeld  1989    89
# 6                    Community  2009    88
# 7     Buffy the Vampire Slayer  1997    84
# 8                     Sherlock  2010    78
# 9                   Mindhunter  2017    97
# 10                     Fleabag  2016   100
# 11          Marvel's Daredevil  2015    92
# 12   The Marvelous Mrs. Maisel  2017    89
# 13                Black Mirror  2011    84
# 14                     Friends  1994    79
# 15                    The Boys  2019    93
# 16               Downton Abbey  2010    91
# 17              Schitt's Creek  2015    93
# 18                       Ozark  2017    83
# 19        Parks and Recreation  2009    93
# 20                  The Office  2005    81
# 21             Game of Thrones  2011    89
# 22                Breaking Bad  2008    96
# 23             The Mandalorian  2019    93
# 24             Stranger Things  2016    91
#
#                                              Director  \
# 0   Mike Flanagan, Trevor Macy, Meredith Averill, ...
# 1
# 2   Jonathan Nolan, Lisa Joy, J.J. Abrams, Athena ...
# 3   Andrew McCarthy, Phil Abraham, Tara Herrmann, ...
# 4                                         Nathan Hope
# 5            Larry David, George Shapiro, Howard West
# 6   Russ Krasnoff, Dan Harmon, Joe Russo, Anthony ...
# 7                Joss Whedon, Marti Noxon, David Fury
# 8                                       Paul McGuigan
# 9   David Fincher, Joshua Donen, Charlize Theron, ...
# 10                                     Harry Bradbeer
# 11    Drew Goddard, Jeph Loeb, Erik Oleson, Jim Chory
# 12            Daniel Palladino, Amy Sherman-Palladino
# 13                     Annabel Jones, Charlie Brooker
# 14  Kevin S. Bright, David Crane, Greg Malins, Wil...
# 15  Eric Kripke, Seth Rogen, Evan Goldberg, James ...
# 16                                    Julian Fellowes
# 17  Andrew Barnsley, Daniel Levy, Eugene Levy, Fre...
# 18  Jason Bateman, Chris Mundy, Bill Dubuque, Mark...
# 19  Greg Daniels, Michael Schur, Howard Klein, Dav...
# 20  Ben Silverman, Greg Daniels, Ricky Gervais, St...
# 21                          David Benioff, D.B. Weiss
# 22  Vince Gilligan, Mark Johnson, Michelle MacLare...
# 23        Dave Filoni, Kathleen Kennedy, Colin Wilson
# 24    Matt Duffer, Ross Duffer, Shawn Levy, Dan Cohen
#
#                                              Synopsis  \
# 0    This modern reimagining of the Shirley Jackso...
# 1    Twelve amateur bakers compete against each ot...
# 2    Westworld isn't your typical amusement park. ...
# 3    Piper Chapman is a public relations executive...
# 4    Based on characters created by Neil Gaiman, S...
# 5    Four single friends -- comic Jerry Seinfeld, ...
# 6    When fast-talking lawyer Jeff Winger (Joel Mc...
# 7    Sarah Michelle Gellar takes on the role of Bu...
# 8    In this contemporary version of Sir Arthur Co...
# 9    Catching a criminal often requires the author...
# 10   A dry-witted woman, known only as Fleabag, ha...
# 11   The first in a planned series of shows detail...
# 12   It's the late 1950s and Miriam "Midge" Maisel...
# 13   Featuring stand-alone dramas -- sharp, suspen...
# 14   Three young men and three young women -- of t...
# 15   Superheroes are often as popular as celebriti...
# 16   This British drama series follows the lives o...
# 17   In the sitcom "Schitt's Creek," a wealthy cou...
# 18   Created by Bill Dubuque ("The Accountant," "T...
# 19   Leslie Knope, a midlevel bureaucrat in an Ind...
# 20   This U.S. adaptation -- set at a paper compan...
# 21   George R.R. Martin's best-selling book series...
# 22   Mild-mannered high school chemistry teacher W...
# 23   After the fall of the Galactic Empire, a lone...
# 24   Mysteries unravel in a small Midwestern town ...
#
#                                                  Cast      Genre  \
# 0   Michiel Huisman, Carla Gugino, Timothy Hutton,...  webseries
# 1   Paul Hollywood, Noel Fielding, Prue Leith, Mat...  webseries
# 2   Evan Rachel Wood, Thandie Newton, Ed Harris, J...  webseries
# 3   Taylor Schilling, Natasha Lyonne, Uzo Aduba, D...  webseries
# 4   Tom Ellis, Lauren German, DB Woodside, Kevin A...  webseries
# 5   Jerry Seinfeld, Julia Louis-Dreyfus, Jason Ale...  webseries
# 6   Joel McHale, Gillian Jacobs, Danny Pudi, Aliso...  webseries
# 7   Sarah Michelle Gellar, Nicholas Brendon, Alyso...  webseries
# 8   Benedict Cumberbatch, Martin Freeman, Andrew S...  webseries
# 9   Jonathan Groff, Holt McCallany, Anna Torv, Joe...  webseries
# 10  Phoebe Waller-Bridge, Ben Aldridge, Sian Cliff...  webseries
# 11  Charlie Cox, Elodie Yung, Deborah Ann Woll, El...  webseries
# 12  Rachel Brosnahan, Michael Zegen, Alex Borstein...  webseries
# 13                                                     webseries
# 14  Jennifer Aniston, Courteney Cox Arquette, Lisa...  webseries
# 15  Karl Urban, Jack Quaid, Antony Starr, Erin Mor...  webseries
# 16  Maggie Smith, Hugh Bonneville, Elizabeth McGov...  webseries
# 17  Eugene Levy, Catherine O'Hara, Daniel Levy, An...  webseries
# 18  Jason Bateman, Laura Linney, Sofia Hublitz, Sk...  webseries
# 19  Amy Poehler, Aziz Ansari, Nick Offerman, Aubre...  webseries
# 20  Steve Carell, Rainn Wilson, John Krasinski, Je...  webseries
# 21  Peter Dinklage, Nikolaj Coster-Waldau, Lena He...  webseries
# 22    Bryan Cranston, Aaron Paul, Anna Gunn, RJ Mitte  webseries
# 23  Pedro Pascal, Gina Carano, Carl Weathers, Gian...  webseries
# 24  Winona Ryder, David Harbour, Millie Bobby Brow...  webseries
#
#    Critic_Consensus Platform
# 0                     public
# 1                     public
# 2                     public
# 3                     public
# 4                     public
# 5                     public
# 6                     public
# 7                     public
# 8                     public
# 9                     public
# 10                    public
# 11                    public
# 12                    public
# 13                    public
# 14                    public
# 15                    public
# 16                    public
# 17                    public
# 18                    public
# 19                    public
# 20                    public
# 21                    public
# 22                    public
# 23                    public
# 24                    public

# %%
movies_r = pd.read_csv("movies_r.csv")
movies_r
# Out:
#                                Movie Title  Year  Score  \
# 0     The Hitchhiker's Guide to the Galaxy  2005     60
# 1                              The Endless  2017     92
# 2                               Timecrimes  2007     90
# 3                                 Ad Astra  2019     83
# 4                                Westworld  1973     85
# ...                                    ...   ...    ...
# 2108        All Quiet on the Western Front  1930     98
# 2109                               Dunkirk  2017     92
# 2110                 The Battle of Algiers  1966     99
# 2111                        Grand Illusion  1937     97
# 2112                            Casablanca  1942     99
#
#                            Director  \
# 0                    Garth Jennings
# 1     Aaron Moorhead, Justin Benson
# 2                   Nacho Vigalondo
# 3                        James Gray
# 4                  Michael Crichton
# ...                             ...
# 2108                Lewis Milestone
# 2109              Christopher Nolan
# 2110               Gillo Pontecorvo
# 2111                    Jean Renoir
# 2112                 Michael Curtiz
#
#                                                Synopsis  \
# 0      Arthur Dent (Martin Freeman) is trying to pre...
# 1      Two brothers receive a cryptic video message ...
# 2      Nacho Vigalondo's time-travel thriller opens ...
# 3      Thirty years ago, Clifford McBride led a voya...
# 4      Westworld is a futuristic theme park where pa...
# ...                                                 ...
# 2108   The film follows a group of German schoolboys...
# 2109   In May 1940, Germany advanced into France, tr...
# 2110   Paratrooper commander Colonel Mathieu (Jean M...
# 2111   A group of French soldiers, including the pat...
# 2112   Rick Blaine (Humphrey Bogart), who owns a nig...
#
#                                                    Cast  Genre  \
# 0     Martin Freeman, Mos Def, Sam Rockwell, Zooey D...  scifi
# 1     Aaron Moorhead, Justin Benson, Callie Hernande...  scifi
# 2     Karra Elejalde, Candela Fernández, Bárbara Goe...  scifi
# 3     Brad Pitt, Tommy Lee Jones, Ruth Negga, Donald...  scifi
# 4     Yul Brynner, Richard Benjamin, James Brolin, N...  scifi
# ...                                                 ...    ...
# 2108  Lew Ayres, Louis Wolheim, John Wray, Raymond G...    war
# 2109  Fionn Whitehead, Tom Glynn-Carney, Jack Lowden...    war
# 2110  Jean Martin, Yacef Saadi, Brahim Haggiag, Tomm...    war
# 2111  Pierre Fresnay, Erich von Stroheim, Jean Gabin...    war
# 2112  Humphrey Bogart, Ingrid Bergman, Paul Henreid,...    war
#
#                                        Critic_Consensus Platform
# 0     A frantic and occasional funny adaptation of D...   Public
# 1     The Endless benefits from its grounded approac...   Public
# 2     Timecrimes is a low-budget thriller that's wel...   Public
# 3     Ad Astra takes a visually thrilling journey th...   Public
# 4     Yul Brynner gives a memorable performance as a...   Public
# ...                                                 ...      ...
# 2108  Director Lewis Milestone's brilliant anti-war ...   public
# 2109  Dunkirk serves up emotionally satisfying spect...   public
# 2110  A documentary-like depiction of a nation's rea...   public
# 2111  Jean Renoir's Grand Illusion is a masterful an...   public
# 2112  An undisputed masterpiece and perhaps Hollywoo...   public
#
# [2113 rows x 9 columns]

# %%
movies_r = pd.concat([movies_r, movies_info], ignore_index = True)
movies_r.reset_index()
movies_r
# Out:
#                                Movie Title  Year Score  \
# 0     The Hitchhiker's Guide to the Galaxy  2005    60
# 1                              The Endless  2017    92
# 2                               Timecrimes  2007    90
# 3                                 Ad Astra  2019    83
# 4                                Westworld  1973    85
# ...                                    ...   ...   ...
# 2133                            The Office  2005    81
# 2134                       Game of Thrones  2011    89
# 2135                          Breaking Bad  2008    96
# 2136                       The Mandalorian  2019    93
# 2137                       Stranger Things  2016    91
#
#                                                Director  \
# 0                                        Garth Jennings
# 1                         Aaron Moorhead, Justin Benson
# 2                                       Nacho Vigalondo
# 3                                            James Gray
# 4                                      Michael Crichton
# ...                                                 ...
# 2133  Ben Silverman, Greg Daniels, Ricky Gervais, St...
# 2134                          David Benioff, D.B. Weiss
# 2135  Vince Gilligan, Mark Johnson, Michelle MacLare...
# 2136        Dave Filoni, Kathleen Kennedy, Colin Wilson
# 2137    Matt Duffer, Ross Duffer, Shawn Levy, Dan Cohen
#
#                                                Synopsis  \
# 0      Arthur Dent (Martin Freeman) is trying to pre...
# 1      Two brothers receive a cryptic video message ...
# 2      Nacho Vigalondo's time-travel thriller opens ...
# 3      Thirty years ago, Clifford McBride led a voya...
# 4      Westworld is a futuristic theme park where pa...
# ...                                                 ...
# 2133   This U.S. adaptation -- set at a paper compan...
# 2134   George R.R. Martin's best-selling book series...
# 2135   Mild-mannered high school chemistry teacher W...
# 2136   After the fall of the Galactic Empire, a lone...
# 2137   Mysteries unravel in a small Midwestern town ...
#
#                                                    Cast      Genre  \
# 0     Martin Freeman, Mos Def, Sam Rockwell, Zooey D...      scifi
# 1     Aaron Moorhead, Justin Benson, Callie Hernande...      scifi
# 2     Karra Elejalde, Candela Fernández, Bárbara Goe...      scifi
# 3     Brad Pitt, Tommy Lee Jones, Ruth Negga, Donald...      scifi
# 4     Yul Brynner, Richard Benjamin, James Brolin, N...      scifi
# ...                                                 ...        ...
# 2133  Steve Carell, Rainn Wilson, John Krasinski, Je...  webseries
# 2134  Peter Dinklage, Nikolaj Coster-Waldau, Lena He...  webseries
# 2135    Bryan Cranston, Aaron Paul, Anna Gunn, RJ Mitte  webseries
# 2136  Pedro Pascal, Gina Carano, Carl Weathers, Gian...  webseries
# 2137  Winona Ryder, David Harbour, Millie Bobby Brow...  webseries
#
#                                        Critic_Consensus Platform
# 0     A frantic and occasional funny adaptation of D...   Public
# 1     The Endless benefits from its grounded approac...   Public
# 2     Timecrimes is a low-budget thriller that's wel...   Public
# 3     Ad Astra takes a visually thrilling journey th...   Public
# 4     Yul Brynner gives a memorable performance as a...   Public
# ...                                                 ...      ...
# 2133                                                      public
# 2134                                                      public
# 2135                                                      public
# 2136                                                      public
# 2137                                                      public
#
# [2138 rows x 9 columns]

# %%
#  write data to CSV file
movies_r.to_csv("movies_r.csv", index = False, header = True)

# %%
df=pd.read_csv("movies_r.csv")
df
# Out:
#                                Movie Title  Year  Score  \
# 0     The Hitchhiker's Guide to the Galaxy  2005     60
# 1                              The Endless  2017     92
# 2                               Timecrimes  2007     90
# 3                                 Ad Astra  2019     83
# 4                                Westworld  1973     85
# ...                                    ...   ...    ...
# 2133                            The Office  2005     81
# 2134                       Game of Thrones  2011     89
# 2135                          Breaking Bad  2008     96
# 2136                       The Mandalorian  2019     93
# 2137                       Stranger Things  2016     91
#
#                                                Director  \
# 0                                        Garth Jennings
# 1                         Aaron Moorhead, Justin Benson
# 2                                       Nacho Vigalondo
# 3                                            James Gray
# 4                                      Michael Crichton
# ...                                                 ...
# 2133  Ben Silverman, Greg Daniels, Ricky Gervais, St...
# 2134                          David Benioff, D.B. Weiss
# 2135  Vince Gilligan, Mark Johnson, Michelle MacLare...
# 2136        Dave Filoni, Kathleen Kennedy, Colin Wilson
# 2137    Matt Duffer, Ross Duffer, Shawn Levy, Dan Cohen
#
#                                                Synopsis  \
# 0      Arthur Dent (Martin Freeman) is trying to pre...
# 1      Two brothers receive a cryptic video message ...
# 2      Nacho Vigalondo's time-travel thriller opens ...
# 3      Thirty years ago, Clifford McBride led a voya...
# 4      Westworld is a futuristic theme park where pa...
# ...                                                 ...
# 2133   This U.S. adaptation -- set at a paper compan...
# 2134   George R.R. Martin's best-selling book series...
# 2135   Mild-mannered high school chemistry teacher W...
# 2136   After the fall of the Galactic Empire, a lone...
# 2137   Mysteries unravel in a small Midwestern town ...
#
#                                                    Cast      Genre  \
# 0     Martin Freeman, Mos Def, Sam Rockwell, Zooey D...      scifi
# 1     Aaron Moorhead, Justin Benson, Callie Hernande...      scifi
# 2     Karra Elejalde, Candela Fernández, Bárbara Goe...      scifi
# 3     Brad Pitt, Tommy Lee Jones, Ruth Negga, Donald...      scifi
# 4     Yul Brynner, Richard Benjamin, James Brolin, N...      scifi
# ...                                                 ...        ...
# 2133  Steve Carell, Rainn Wilson, John Krasinski, Je...  webseries
# 2134  Peter Dinklage, Nikolaj Coster-Waldau, Lena He...  webseries
# 2135    Bryan Cranston, Aaron Paul, Anna Gunn, RJ Mitte  webseries
# 2136  Pedro Pascal, Gina Carano, Carl Weathers, Gian...  webseries
# 2137  Winona Ryder, David Harbour, Millie Bobby Brow...  webseries
#
#                                        Critic_Consensus Platform
# 0     A frantic and occasional funny adaptation of D...   Public
# 1     The Endless benefits from its grounded approac...   Public
# 2     Timecrimes is a low-budget thriller that's wel...   Public
# 3     Ad Astra takes a visually thrilling journey th...   Public
# 4     Yul Brynner gives a memorable performance as a...   Public
# ...                                                 ...      ...
# 2133                                                NaN   public
# 2134                                                NaN   public
# 2135                                                NaN   public
# 2136                                                NaN   public
# 2137                                                NaN   public
#
# [2138 rows x 9 columns]

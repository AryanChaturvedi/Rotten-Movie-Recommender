# %%
import numpy as np
import pandas as pd

# %%
movies= pd.read_csv("movies_all.csv")
movies.head()
# Out:
#                  Movie Title  Year  Score  \
# 0      The Baby-Sitters Club  2020    100
# 1               Heartstopper  2022    100
# 2                 Aggretsuko  2018    100
# 3                Dash & Lily  2020    100
# 4  Arcane: League of Legends  2021    100
#
#                                             Director  \
# 0  Lucia Aniello, Naia Cucukov, Michael De Luca, ...
# 1  Euros Lyn, Iain Canning, Nicky Earnshaw, Hakan...
# 2                                                NaN
# 3  Shawn Levy, Josh Barry, Nick Jonas, Brad Silbe...
# 4  Brandon Beck, Marc Merrill, Nicolo Laurent, Ja...
#
#                                             Synopsis  \
# 0   A group of friends launch a babysitting busin...
# 1   Teens Charlie and Nick discover their unlikel...
# 2   Retsuko is a 25-year-old red panda who is gro...
# 3   A whirlwind Christmas romance builds as cynic...
# 4   The origins of two iconic League champions, s...
#
#                                                 Cast  Genre Critic_Consensus  \
# 0  Sophie Grace, Malia Baker, Momona Tamada, Shay...    NaN              NaN
# 1  Kit Connor, Joe Locke, William Gao, Yasmin Finney    NaN              NaN
# 2           Kaolip, Komegumi Koiwasaki, Maki Tsuruta    NaN              NaN
# 3  Austin Abrams, Midori Francis, Dante Brown, Tr...    NaN              NaN
# 4  Hailee Steinfeld, Katie Leung, Kevin Alejandro...    NaN              NaN
#
#   Platform
# 0  Netflix
# 1  Netflix
# 2  Netflix
# 3  Netflix
# 4  Netflix

# %%
movies.shape
# Out:
# (2129, 9)

# %%
movies.fillna("")
# Out:
#                      Movie Title  Year  Score  \
# 0          The Baby-Sitters Club  2020    100
# 1                   Heartstopper  2022    100
# 2                     Aggretsuko  2018    100
# 3                    Dash & Lily  2020    100
# 4      Arcane: League of Legends  2021    100
# ...                          ...   ...    ...
# 2124                 Hard-Boiled  1992     94
# 2125                  The Matrix  1999     88
# 2126  Terminator 2: Judgment Day  1991     93
# 2127                    Die Hard  1988     94
# 2128          Mad Max: Fury Road  2015     97
#
#                                                Director  \
# 0     Lucia Aniello, Naia Cucukov, Michael De Luca, ...
# 1     Euros Lyn, Iain Canning, Nicky Earnshaw, Hakan...
# 2
# 3     Shawn Levy, Josh Barry, Nick Jonas, Brad Silbe...
# 4     Brandon Beck, Marc Merrill, Nicolo Laurent, Ja...
# ...                                                 ...
# 2124                                           John Woo
# 2125                    Andy Wachowski, Larry Wachowski
# 2126                                      James Cameron
# 2127                                     John McTiernan
# 2128                                      George Miller
#
#                                                Synopsis  \
# 0      A group of friends launch a babysitting busin...
# 1      Teens Charlie and Nick discover their unlikel...
# 2      Retsuko is a 25-year-old red panda who is gro...
# 3      A whirlwind Christmas romance builds as cynic...
# 4      The origins of two iconic League champions, s...
# ...                                                 ...
# 2124   A cop who loses his partner in a shoot-out wi...
# 2125   Neo (Keanu Reeves) believes that Morpheus (La...
# 2126   In this sequel set eleven years after "The Te...
# 2127   New York City policeman John McClane (Bruce W...
# 2128   Years after the collapse of civilization, the...
#
#                                                    Cast Genre  \
# 0     Sophie Grace, Malia Baker, Momona Tamada, Shay...
# 1     Kit Connor, Joe Locke, William Gao, Yasmin Finney
# 2              Kaolip, Komegumi Koiwasaki, Maki Tsuruta
# 3     Austin Abrams, Midori Francis, Dante Brown, Tr...
# 4     Hailee Steinfeld, Katie Leung, Kevin Alejandro...
# ...                                                 ...   ...
# 2124  Chow Yun-Fat, Bowie Lam, Philip Chan, Tony Leu...
# 2125  Keanu Reeves, Laurence Fishburne, Carrie-Anne ...
# 2126  Arnold Schwarzenegger, Linda Hamilton, Edward ...
# 2127  Bruce Willis, Alan Rickman, Bonnie Bedelia, Re...
# 2128  Tom Hardy, Charlize Theron, Nicholas Hoult, Hu...
#
#                                        Critic_Consensus Platform
# 0                                                        Netflix
# 1                                                        Netflix
# 2                                                        Netflix
# 3                                                        Netflix
# 4                                                        Netflix
# ...                                                 ...      ...
# 2124  Boasting impactful action as well as surprisin...   Public
# 2125  Thanks to the Wachowskis' imaginative vision, ...   Public
# 2126  T2 features thrilling action sequences and eye...   Public
# 2127  Its many imitators (and sequels) have never co...   Public
# 2128  With exhilarating action and a surprising amou...   Public
#
# [2129 rows x 9 columns]

# %%
movies['Year']= movies['Year'].map(str)
movies['Score']= movies['Score'].map(str)

# %%
# df['d'] = df[['a', 'b', 'c']].fillna('').agg('|'.join, axis=1)
movies['tag']= movies[['Director','Synopsis','Cast','Critic_Consensus','Score','Year']].fillna("").agg(' '.join,axis=1)
movies.head(5)
# Out:
#                  Movie Title  Year Score  \
# 0      The Baby-Sitters Club  2020   100
# 1               Heartstopper  2022   100
# 2                 Aggretsuko  2018   100
# 3                Dash & Lily  2020   100
# 4  Arcane: League of Legends  2021   100
#
#                                             Director  \
# 0  Lucia Aniello, Naia Cucukov, Michael De Luca, ...
# 1  Euros Lyn, Iain Canning, Nicky Earnshaw, Hakan...
# 2                                                NaN
# 3  Shawn Levy, Josh Barry, Nick Jonas, Brad Silbe...
# 4  Brandon Beck, Marc Merrill, Nicolo Laurent, Ja...
#
#                                             Synopsis  \
# 0   A group of friends launch a babysitting busin...
# 1   Teens Charlie and Nick discover their unlikel...
# 2   Retsuko is a 25-year-old red panda who is gro...
# 3   A whirlwind Christmas romance builds as cynic...
# 4   The origins of two iconic League champions, s...
#
#                                                 Cast  Genre Critic_Consensus  \
# 0  Sophie Grace, Malia Baker, Momona Tamada, Shay...    NaN              NaN
# 1  Kit Connor, Joe Locke, William Gao, Yasmin Finney    NaN              NaN
# 2           Kaolip, Komegumi Koiwasaki, Maki Tsuruta    NaN              NaN
# 3  Austin Abrams, Midori Francis, Dante Brown, Tr...    NaN              NaN
# 4  Hailee Steinfeld, Katie Leung, Kevin Alejandro...    NaN              NaN
#
#   Platform                                                tag
# 0  Netflix  Lucia Aniello, Naia Cucukov, Michael De Luca, ...
# 1  Netflix  Euros Lyn, Iain Canning, Nicky Earnshaw, Hakan...
# 2  Netflix    Retsuko is a 25-year-old red panda who is gr...
# 3  Netflix  Shawn Levy, Josh Barry, Nick Jonas, Brad Silbe...
# 4  Netflix  Brandon Beck, Marc Merrill, Nicolo Laurent, Ja...

# %%
movies = movies.drop(columns= ['Director','Genre','Platform','Synopsis','Cast','Critic_Consensus','Score','Year'])
movies.sample(5)
# Out:
#          Movie Title                                                tag
# 21          Fanático  Roger Gual  After music artist Quimera dies on...
# 1963   Monster House  Gil Kenan  No adults believe three youths' (Mi...
# 110   Whose Streets?  Sabaah Folayan  An account of the Ferguson upr...
# 1444    The Sopranos  David Chase, Timothy Van Patten, John Patterso...
# 1885          WALL-E  Andrew Stanton  WALL-E, short for Waste Alloca...

# %%
movies['tag'][4]
# Out:
# 'Brandon Beck, Marc Merrill, Nicolo Laurent, Jane Chung  The origins of two iconic League champions, set in the utopian Piltover and the oppressed underground of Zaun.... Hailee Steinfeld, Katie Leung, Kevin Alejandro, Jason Spisak  100 2021'

# %%
# converting in lowercase
movies['title'] = movies['Movie Title']
movies['tag'] = movies['tag'].str.lower()
movies.sample(5)
# Out:
#               Movie Title                                                tag  \
# 517                 Ailey  jamila wignot  alvin ailey was a trailblazing ...
# 836   One Cut of the Dead  shinichiro ueda  real zombies attack a hack di...
# 1939      Kung Fu Panda 3  jennifer yuh nelson, alessandro carloni  livin...
# 690              The Wind  emma tammi  lizzy is a tough, resourceful fron...
# 142   Sorry to Bother You  boots riley  in an alternate reality of presen...
#
#                     title
# 517                 Ailey
# 836   One Cut of the Dead
# 1939      Kung Fu Panda 3
# 690              The Wind
# 142   Sorry to Bother You

# %%
# remove html tags
import re
def remove_html_tags(text):
    pattern = re.compile('<.*?>')
    return pattern.sub(r'', text)

# %%
movies['tag'] = movies['tag'].apply(remove_html_tags)
movies.sample(5)
# Out:
#             Movie Title                                                tag  \
# 486     The Night House  david bruckner  reeling from the unexpected de...
# 2038          The Guest  adam wingard  a string of mysterious deaths le...
# 303   Writing with Fire  rintu thomas, sushmit ghosh  armed with smartp...
# 628               Sweat  magnus von horn  beloved fitness influencer sy...
# 1881                 Up  pete docter, bob peterson  carl fredricksen (e...
#
#                   title
# 486     The Night House
# 2038          The Guest
# 303   Writing with Fire
# 628               Sweat
# 1881                 Up

# %%
# remove punctuation
import string
exclude = string.punctuation
def remove_punc1(text):
    return text.translate(str.maketrans('', '', exclude))


movies['tag'].apply(remove_punc1)
movies.sample(5)
# Out:
#        Movie Title                                                tag  \
# 501        Memoria  apichatpong weerasethakul  ever since being st...
# 1866  Finding Nemo  andrew stanton  marlin (albert brooks), a clow...
# 1671     Nomadland  chloé zhao  a woman embarks on a journey throu...
# 1118        Clouds  justin baldoni  teenager zach sobiech forms th...
# 74       Hit & Run  lior raz, avi issacharoff, dawn prestwich, nic...
#
#              title
# 501        Memoria
# 1866  Finding Nemo
# 1671     Nomadland
# 1118        Clouds
# 74       Hit & Run

# %%
from nltk.corpus import stopwords

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Aryan
# [nltk_data]     Chaturvedi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopwords.words('english')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
def remove_stopwords(text):
    new_text = []
    
    for word in text.split():
        if word in stopwords.words('english'):
            new_text.append('')
        else:
            new_text.append(word)
    x = new_text[:]
    new_text.clear()
    return " ".join(x)

# %%
movies['tag'][2]
# Out:
# '  retsuko is a 25-year-old red panda who is growing increasingly frustrated with her job in the accounting department of a... kaolip, komegumi koiwasaki, maki tsuruta  100 2018'

# %%
movies['tag']= movies['tag'].apply(remove_stopwords)

# %%
movies['tag'][2]
# Out:
# 'retsuko   25-year-old red panda   growing increasingly frustrated   job   accounting department  a... kaolip, komegumi koiwasaki, maki tsuruta 100 2018'

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(stop_words='english')

# %%
vector = cv.fit_transform(movies['tag'])
vector.shape
# Out:
# (2129, 17129)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vector)

# %%
similarity.shape
# Out:
# (2129, 2129)

# %%
similarity[0]
# Out:
# array([1.        , 0.03857584, 0.04682929, ..., 0.        , 0.        ,
#        0.        ])

# %%
movies[movies['title']=='The Matrix'].index[0]
# Out:
# 2125

# %%
def recommend(movie):
    index = movies[movies['title'] == movie].index[0]
    distances = sorted(list(enumerate(similarity[index])),reverse=True,key = lambda x: x[1])
    for i in distances[1:6]:
        print(movies.iloc[i[0]].title)

# %%
recommend('Mad Max: Fury Road')
# Out:
# Mad Max 2: The Road Warrior
# Finch
# Finch
# National Treasure
# The Amusement Park
